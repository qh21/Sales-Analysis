# %% [markdown]
# # Data analysis is the process of inspecting, cleaning, transforming, and modeling data with the goal of discovering useful information, drawing conclusions, and supporting decision-making. It involves various techniques and methods to uncover patterns, trends, correlations, and insights from structured and unstructured data.
#
# # In the context of sales analysis, data analysis plays a crucial role in extracting actionable information from sales-related datasets.
#
# # Here are some questions and insights that we are going to explore that can help in our case study:
#
# # 1.Temporal Patterns:
#
# # How does the number of units sold vary over time?
# # Is there a noticeable trend in revenue over the given dates?
# # Are there any specific dates or months where sales are consistently higher or lower?
#
# # 2. Geographical Analysis:
#
# # What are the sales patterns across different zip codes?
# # Is there a correlation between the zip code and the number of units sold or revenue generated?
# # Are there specific countries that contribute significantly to the sales?
#
# # 3. Product Analysis:
#
# # How does the performance of ProductID 1082 compare to other products in the dataset?
# # Is there a consistent pricing strategy for ProductID 1082, given the constant revenue for each unit sold?
#
# # 4. Country-wise Insights:
#
# # Are there variations in sales performance between different countries?
# # Do certain countries prefer this product  (ProductID 1082) more than others?
#
#
# # 5. Overall Summary:
#
# # What is the overall performance of ProductID 1082 in terms of units sold and revenue generated?

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Reading and Discovering the Datasets

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Australia = pd.read_csv('Australia.csv')
Australia
# Out:
#          ProductID        Date   Zip  Units   Revenue    Country
# 0             1070  2020-01-18  2128      1  157.4475  Australia
# 1             1070  2020-04-02  2565      1  157.4475  Australia
# 2             1070  2020-04-25  4581      4  629.7900  Australia
# 3             1070  2020-04-26  1189      2  314.8950  Australia
# 4             1070  2020-04-26  3981      1  157.4475  Australia
# ...            ...         ...   ...    ...       ...        ...
# 1992230        964  2016-02-10  2422      1  314.9475  Australia
# 1992231        964  2016-02-10  3898      1  335.9475  Australia
# 1992232        964  2016-02-12  1006      1  335.9475  Australia
# 1992233        964  2016-02-12   221      1  330.6975  Australia
# 1992234        964  2016-02-12  3165      1  330.6975  Australia
#
# [1992235 rows x 6 columns]

# %%
Australia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1992235 entries, 0 to 1992234
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   ProductID  int64
#  1   Date       object
#  2   Zip        int64
#  3   Units      int64
#  4   Revenue    float64
#  5   Country    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 91.2+ MB

# %%
Australia.isna().sum()
# Out:
# ProductID    0
# Date         0
# Zip          0
# Units        0
# Revenue      0
# Country      0
# dtype: int64

# %%
Canada = pd.read_csv('Canada.csv')
Canada
# Out:
#        ProductID        Date  Zip  Units    Revenue Country
# 0           1082  2014-06-28  R3E      1   225.6975  Canada
# 1           1082  2014-12-14  M6H      1   230.9475  Canada
# 2           1082  2015-05-03  L5T      1   230.9475  Canada
# 3           1082  2017-05-14  R3B      1   230.9475  Canada
# 4           1082  2017-06-30  T6J      1   230.9475  Canada
# ...          ...         ...  ...    ...        ...     ...
# 46099        663  2013-03-15  T2J      1   765.4500  Canada
# 46100        495  2013-07-15  M4Y      5  2804.8125  Canada
# 46101        495  2013-09-15  H3A      1   577.5000  Canada
# 46102        495  2014-10-02  T6R      1   577.9200  Canada
# 46103        631  2013-01-15  T6T      1   346.2375  Canada
#
# [46104 rows x 6 columns]

# %%
Canada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46104 entries, 0 to 46103
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ProductID  46104 non-null  int64
#  1   Date       46104 non-null  object
#  2   Zip        46104 non-null  object
#  3   Units      46104 non-null  int64
#  4   Revenue    46104 non-null  float64
#  5   Country    46104 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
Germany = pd.read_csv('Germany.csv')
Germany
# Out:
#         ProductID        Date    Zip  Units  Revenue  Country
# 0            1052  2020-03-24  13591      1   246.70  Germany
# 1            1052  2020-03-31  46045      1   246.70  Germany
# 2            1052  2020-04-28  22417      1   246.70  Germany
# 3            1052  2020-06-21  50968      1   246.70  Germany
# 4            1052  2020-08-15  52538      1   246.70  Germany
# ...           ...         ...    ...    ...      ...      ...
# 137614       1062  2018-05-27  10115      1   149.57  Germany
# 137615       1062  2018-05-28  52379      1   149.57  Germany
# 137616       1062  2018-06-21  53343      1   141.70  Germany
# 137617       1062  2018-07-16  46414      1   141.70  Germany
# 137618       1062  2018-07-28  45145      1   149.57  Germany
#
# [137619 rows x 6 columns]

# %%
Germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137619 entries, 0 to 137618
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ProductID  137619 non-null  int64
#  1   Date       137619 non-null  object
#  2   Zip        137619 non-null  int64
#  3   Units      137619 non-null  int64
#  4   Revenue    137619 non-null  float64
#  5   Country    137619 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 6.3+ MB

# %%
Japan = pd.read_csv('Japan.csv')
Japan
# Out:
#         ProductID        Date       Zip  Units   Revenue Country
# 0            1085  2019-07-19  961-0917      1   86.5725   Japan
# 1            1085  2019-07-29  747-0004      1   86.5725   Japan
# 2            1085  2019-08-06  750-0052      1   86.5725   Japan
# 3            1085  2019-08-10  720-2106      2  173.1450   Japan
# 4            1085  2019-08-13  747-0044      1   86.5725   Japan
# ...           ...         ...       ...    ...       ...     ...
# 527299        762  2019-03-27  722-2417      2  367.3950   Japan
# 527300        762  2019-03-27  747-0067      1  183.6975   Japan
# 527301        762  2019-03-31  779-3118      1  183.6975   Japan
# 527302        762  2019-04-21  721-0915      1  178.4475   Japan
# 527303        762  2019-04-29  960-0753      1  183.6975   Japan
#
# [527304 rows x 6 columns]

# %%
Japan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527304 entries, 0 to 527303
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ProductID  527304 non-null  int64
#  1   Date       527304 non-null  object
#  2   Zip        527304 non-null  object
#  3   Units      527304 non-null  int64
#  4   Revenue    527304 non-null  float64
#  5   Country    527304 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 24.1+ MB

# %%
Mexico = pd.read_csv('Mexico.csv')
Mexico
# Out:
#         ProductID        Date    Zip  Units  Revenue Country
# 0            1052  2020-03-31   9510      1   246.70  Mexico
# 1            1052  2020-04-17  12400      1   246.70  Mexico
# 2            1052  2020-08-29   9719      1   246.70  Mexico
# 3            1053  2013-04-15   2260      1   251.95  Mexico
# 4            1057  2017-06-16   7909      1   136.45  Mexico
# ...           ...         ...    ...    ...      ...     ...
# 128566       1061  2014-06-05   7880      1   141.70  Mexico
# 128567       1062  2016-07-17   7380      1   149.57  Mexico
# 128568       1061  2014-03-08  10330      1   141.70  Mexico
# 128569       1061  2014-03-16   5509      1   141.70  Mexico
# 128570       1053  2020-08-25   9540      1   272.95  Mexico
#
# [128571 rows x 6 columns]

# %%
Mexico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128571 entries, 0 to 128570
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ProductID  128571 non-null  int64
#  1   Date       128571 non-null  object
#  2   Zip        128571 non-null  int64
#  3   Units      128571 non-null  int64
#  4   Revenue    128571 non-null  float64
#  5   Country    128571 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.9+ MB

# %%
Nigeria = pd.read_csv('Nigeria.csv')
Nigeria
# Out:
#         ProductID        Date     Zip  Units  Revenue  Country
# 0            2136   5/12/2020  101001      1   419.95  Nigeria
# 1            2055    5/4/2015  101001      1   569.57  Nigeria
# 2            2055   5/17/2016  101001      1   569.57  Nigeria
# 3            2055    6/5/2016  101001      1   569.57  Nigeria
# 4            2055  10/29/2016  101001      1   569.57  Nigeria
# ...           ...         ...     ...    ...      ...      ...
# 205363       2192   8/21/2014  700001      1   204.70      NaN
# 205364       2235  12/31/2016  700001      1    70.82      NaN
# 205365       1987   4/12/2020  700001      2   325.40      NaN
# 205366       2255   6/28/2016  700001      1    60.32      NaN
# 205367       2252   7/26/2015  700001      1   136.45      NaN
#
# [205368 rows x 6 columns]

# %%
Nigeria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205368 entries, 0 to 205367
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ProductID  205368 non-null  int64
#  1   Date       205368 non-null  object
#  2   Zip        205368 non-null  int64
#  3   Units      205368 non-null  int64
#  4   Revenue    205368 non-null  float64
#  5   Country    204904 non-null  object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.4+ MB

# %%
Nigeria.isna().sum()
# Out:
# ProductID      0
# Date           0
# Zip            0
# Units          0
# Revenue        0
# Country      464
# dtype: int64

# %%
Nigeria = Nigeria.fillna('Nigeria')

# %%
Nigeria
# Out:
#         ProductID        Date     Zip  Units  Revenue  Country
# 0            2136   5/12/2020  101001      1   419.95  Nigeria
# 1            2055    5/4/2015  101001      1   569.57  Nigeria
# 2            2055   5/17/2016  101001      1   569.57  Nigeria
# 3            2055    6/5/2016  101001      1   569.57  Nigeria
# 4            2055  10/29/2016  101001      1   569.57  Nigeria
# ...           ...         ...     ...    ...      ...      ...
# 205363       2192   8/21/2014  700001      1   204.70  Nigeria
# 205364       2235  12/31/2016  700001      1    70.82  Nigeria
# 205365       1987   4/12/2020  700001      2   325.40  Nigeria
# 205366       2255   6/28/2016  700001      1    60.32  Nigeria
# 205367       2252   7/26/2015  700001      1   136.45  Nigeria
#
# [205368 rows x 6 columns]

# %%
Nigeria.isna().sum()
# Out:
# ProductID    0
# Date         0
# Zip          0
# Units        0
# Revenue      0
# Country      0
# dtype: int64

# %%
df = pd.concat([Australia, Canada, Germany, Japan, Mexico, Nigeria], axis=0)

# %%
df
# Out:
#         ProductID        Date     Zip  Units   Revenue    Country
# 0            1070  2020-01-18    2128      1  157.4475  Australia
# 1            1070  2020-04-02    2565      1  157.4475  Australia
# 2            1070  2020-04-25    4581      4  629.7900  Australia
# 3            1070  2020-04-26    1189      2  314.8950  Australia
# 4            1070  2020-04-26    3981      1  157.4475  Australia
# ...           ...         ...     ...    ...       ...        ...
# 205363       2192   8/21/2014  700001      1  204.7000    Nigeria
# 205364       2235  12/31/2016  700001      1   70.8200    Nigeria
# 205365       1987   4/12/2020  700001      2  325.4000    Nigeria
# 205366       2255   6/28/2016  700001      1   60.3200    Nigeria
# 205367       2252   7/26/2015  700001      1  136.4500    Nigeria
#
# [3037201 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3037201 entries, 0 to 205367
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   ProductID  int64
#  1   Date       object
#  2   Zip        object
#  3   Units      int64
#  4   Revenue    float64
#  5   Country    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 162.2+ MB

# %%
df.isnull().sum()
# Out:
# ProductID    0
# Date         0
# Zip          0
# Units        0
# Revenue      0
# Country      0
# dtype: int64

# %% [markdown]
# ## After concatenating datasets and checking that there are no null values, now we are going to make date format the same for all rows then check for duplicates:

# %%
df
# Out:
#         ProductID        Date     Zip  Units   Revenue    Country
# 0            1070  2020-01-18    2128      1  157.4475  Australia
# 1            1070  2020-04-02    2565      1  157.4475  Australia
# 2            1070  2020-04-25    4581      4  629.7900  Australia
# 3            1070  2020-04-26    1189      2  314.8950  Australia
# 4            1070  2020-04-26    3981      1  157.4475  Australia
# ...           ...         ...     ...    ...       ...        ...
# 205363       2192   8/21/2014  700001      1  204.7000    Nigeria
# 205364       2235  12/31/2016  700001      1   70.8200    Nigeria
# 205365       1987   4/12/2020  700001      2  325.4000    Nigeria
# 205366       2255   6/28/2016  700001      1   60.3200    Nigeria
# 205367       2252   7/26/2015  700001      1  136.4500    Nigeria
#
# [3037201 rows x 6 columns]

# %%
possible_formats = ['%m/%d/%Y', '%Y-%m-%d', '%d-%m-%Y', '%m/%d/%y', '%Y%m%d', '%d/%m/%Y']

for fmt in possible_formats:
    try:
        df['Date'] = pd.to_datetime(df['Date'], format=fmt)
        break
    except ValueError:
        pass

# %%
df
# Out:
#         ProductID        Date     Zip  Units   Revenue    Country
# 0            1070  2020-01-18    2128      1  157.4475  Australia
# 1            1070  2020-04-02    2565      1  157.4475  Australia
# 2            1070  2020-04-25    4581      4  629.7900  Australia
# 3            1070  2020-04-26    1189      2  314.8950  Australia
# 4            1070  2020-04-26    3981      1  157.4475  Australia
# ...           ...         ...     ...    ...       ...        ...
# 205363       2192   8/21/2014  700001      1  204.7000    Nigeria
# 205364       2235  12/31/2016  700001      1   70.8200    Nigeria
# 205365       1987   4/12/2020  700001      2  325.4000    Nigeria
# 205366       2255   6/28/2016  700001      1   60.3200    Nigeria
# 205367       2252   7/26/2015  700001      1  136.4500    Nigeria
#
# [3037201 rows x 6 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# %%
df
# Out:
#         ProductID       Date     Zip  Units   Revenue    Country
# 0            1070 2020-01-18    2128      1  157.4475  Australia
# 1            1070 2020-04-02    2565      1  157.4475  Australia
# 2            1070 2020-04-25    4581      4  629.7900  Australia
# 3            1070 2020-04-26    1189      2  314.8950  Australia
# 4            1070 2020-04-26    3981      1  157.4475  Australia
# ...           ...        ...     ...    ...       ...        ...
# 205363       2192 2014-08-21  700001      1  204.7000    Nigeria
# 205364       2235 2016-12-31  700001      1   70.8200    Nigeria
# 205365       1987 2020-04-12  700001      2  325.4000    Nigeria
# 205366       2255 2016-06-28  700001      1   60.3200    Nigeria
# 205367       2252 2015-07-26  700001      1  136.4500    Nigeria
#
# [3037201 rows x 6 columns]

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df
# Out:
#         ProductID       Date     Zip  Units   Revenue    Country
# 0            1070 2020-01-18    2128      1  157.4475  Australia
# 1            1070 2020-04-02    2565      1  157.4475  Australia
# 2            1070 2020-04-25    4581      4  629.7900  Australia
# 3            1070 2020-04-26    1189      2  314.8950  Australia
# 4            1070 2020-04-26    3981      1  157.4475  Australia
# ...           ...        ...     ...    ...       ...        ...
# 204898       2254 2019-05-03  700001      1   56.6500    Nigeria
# 204899       2192 2014-08-21  700001      1  204.7000    Nigeria
# 204900       2235 2016-12-31  700001      1   70.8200    Nigeria
# 204901       1987 2020-04-12  700001      2  325.4000    Nigeria
# 204903       2252 2015-07-26  700001      1  136.4500    Nigeria
#
# [2778735 rows x 6 columns]

# %% [markdown]
# # Now let's answer the questions
#
# ## How does the number of units sold vary over time?

# %%
df['Month'] = df['Date'].dt.to_period('M')
df
# Out:
# C:\Users\Qassem\AppData\Local\Temp\ipykernel_13240\1256024396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month'] = df['Date'].dt.to_period('M')
#         ProductID       Date     Zip  Units   Revenue    Country    Month
# 0            1070 2020-01-18    2128      1  157.4475  Australia  2020-01
# 1            1070 2020-04-02    2565      1  157.4475  Australia  2020-04
# 2            1070 2020-04-25    4581      4  629.7900  Australia  2020-04
# 3            1070 2020-04-26    1189      2  314.8950  Australia  2020-04
# 4            1070 2020-04-26    3981      1  157.4475  Australia  2020-04
# ...           ...        ...     ...    ...       ...        ...      ...
# ...

# %%
df['Year'] = df['Date'].dt.to_period('Y')
df
# Out:
# C:\Users\Qassem\AppData\Local\Temp\ipykernel_13240\144541211.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Date'].dt.to_period('Y')
#         ProductID       Date     Zip  Units   Revenue    Country    Month  \
# 0            1070 2020-01-18    2128      1  157.4475  Australia  2020-01
# 1            1070 2020-04-02    2565      1  157.4475  Australia  2020-04
# 2            1070 2020-04-25    4581      4  629.7900  Australia  2020-04
# 3            1070 2020-04-26    1189      2  314.8950  Australia  2020-04
# 4            1070 2020-04-26    3981      1  157.4475  Australia  2020-04
# ...           ...        ...     ...    ...       ...        ...      ...
# ...

# %%
df['yearly_total'] = df.groupby('Year')['Units'].transform('sum')
# Out:
# C:\Users\Qassem\AppData\Local\Temp\ipykernel_13240\3860931274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yearly_total'] = df.groupby('Year')['Units'].transform('sum')

# %%
df2 = df[['Year', 'yearly_total']].drop_duplicates()

# %%
df2
# Out:
#      Year  yearly_total
# 0    2020        418073
# 16   2017        392066
# 57   2018        406915
# 91   2015        352275
# 111  2016        379212
# 238  2019        402174
# 281  2014        297092
# 348  2013        226519

# %%
df2 = df2.reset_index(drop=True)

# %%
df2
# Out:
#    Year  yearly_total
# 0  2020        418073
# 1  2017        392066
# 2  2018        406915
# 3  2015        352275
# 4  2016        379212
# 5  2019        402174
# 6  2014        297092
# 7  2013        226519

# %%
sns.lineplot(x=df2['Year'].astype(str), y=df2['yearly_total'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='yearly_total'>

# %%
df2 = df2.sort_values(by='Year', ascending=True)

# %%
df2
# Out:
#    Year  yearly_total
# 7  2013        226519
# 6  2014        297092
# 3  2015        352275
# 4  2016        379212
# 1  2017        392066
# 2  2018        406915
# 5  2019        402174
# 0  2020        418073

# %%
sns.lineplot(x=df2['Year'].astype(str), y=df2['yearly_total'])
plt.xlabel('Year')
plt.ylabel('Total Sold Units')
plt.title('Total Sold Units per Year')
# Out:
# Text(0.5, 1.0, 'Total Sold Units per Year')

# %%
df3 = df.groupby('Zip')['Units'].sum().reset_index()
df3 = df3.sort_values(by='Units', ascending=False)

# Display the top zip codes
print("Top Zip Codes by Total Units Sold:\n\n")
print(df3.head(10))
# Out:
# Top Zip Codes by Total Units Sold:
#
#
#          Zip  Units
# 4692  700001  72698
# 4691  500001  54081
# 4690  101001  42479
# 921     2722   3922
# 525     2162   3844
# 2526    5371   3181
# 1468    3540   3048
# 719     2430   2883
# 1718    3904   2883
# 1352    3350   2869

# %% [markdown]
# ## Is there a noticeable trend in revenue over the given dates?

# %%
df4 = df.groupby('Date')['Revenue'].sum().reset_index()

# Time Series Plot with Aggregated Data
plt.figure(figsize=(20, 12))
plt.plot(df4['Date'], df4['Revenue'], marker='o', linestyle='-', color='b')
plt.title('Aggregated Revenue Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Are there any specific dates or months where sales are consistently higher or lower?

# %%
# Aggregate data by month and year
monthly_aggregated = df.groupby(['Year', 'Month']).agg({'Revenue': 'sum', 'Units': 'sum'}).reset_index()

# Visualize the monthly revenue trend
plt.figure(figsize=(30, 12))
plt.plot(monthly_aggregated['Year'].astype(str) + '-' + monthly_aggregated['Month'].astype(str), monthly_aggregated['Revenue'], marker='o', linestyle='-', color='b')
plt.title('Monthly Revenue Trend')
plt.xlabel('Year-Month')
plt.ylabel('Total Revenue')
plt.xticks(rotation=90, ha='right')
plt.grid(True)
plt.show()

# %% [markdown]
# ## What are the sales patterns across different zip codes?

# %%
# Aggregate data by zip code
zip_code_aggregated = df.groupby('Zip').agg({'Revenue': 'sum', 'Units': 'sum'}).reset_index()

# Sort the data by total revenue to highlight top-contributing zip codes
zip_code_aggregated = zip_code_aggregated.sort_values(by='Revenue', ascending=False)

# Select the top N zip codes (adjust N based on your needs)
top_n = 10
top_zip_codes = zip_code_aggregated.head(top_n)

# Visualize the sales patterns for the top N zip codes
plt.figure(figsize=(12, 6))
plt.bar(top_zip_codes['Zip'].astype(str), top_zip_codes['Revenue'], color='b')
plt.title(f'Top {top_n} Sales Patterns Across Zip Codes')
plt.xlabel('Zip Code')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Is there a correlation between the zip code and the number of units sold or revenue generated?

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df[['Zip', 'Units', 'Revenue']].corr(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix: Zip Code, Units Sold, Revenue')
plt.show()

# %% [markdown]
# ## Are there specific countries that contribute significantly to the sales?

# %%
# Aggregate data by country
country_aggregated = df.groupby('Country').agg({'Revenue': 'sum', 'Units': 'sum'}).reset_index()

# Sort the data by total revenue to highlight top-contributing countries
country_aggregated = country_aggregated.sort_values(by='Revenue', ascending=False)

# Visualize the sales contribution by country
plt.figure(figsize=(12, 6))
plt.bar(country_aggregated['Country'], country_aggregated['Revenue'], color='b')
plt.title('Sales Contribution by Country')
plt.xlabel('Country')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## How does the performance of ProductID 1082 compare to other products in the dataset?

# %%
# Filter data for ProductID 1082
product_1082 = df[df['ProductID'] == 1082]

# Aggregate data for ProductID 1082
product_1082_aggregated = product_1082.groupby('ProductID').agg({'Units': 'sum', 'Revenue': 'sum'}).reset_index()

# Aggregate data for all products (excluding ProductID 1082)
other_products_aggregated = df[df['ProductID'] != 1082].groupby('ProductID').agg({'Units': 'sum', 'Revenue': 'sum'}).reset_index()

# Compare total units sold
plt.bar(['Product 1082', 'Other Products'], [product_1082_aggregated['Units'].values[0], other_products_aggregated['Units'].sum()])
plt.title('Comparison of Total Units Sold')
plt.ylabel('Total Units Sold')
plt.show()

# Compare total revenue generated
plt.bar(['Product 1082', 'Other Products'], [product_1082_aggregated['Revenue'].values[0], other_products_aggregated['Revenue'].sum()])
plt.title('Comparison of Total Revenue Generated')
plt.ylabel('Total Revenue')
plt.show()

# Compare average revenue per unit
average_revenue_per_unit_1082 = product_1082_aggregated['Revenue'].values[0] / product_1082_aggregated['Units'].values[0]
average_revenue_per_unit_other = other_products_aggregated['Revenue'].sum() / other_products_aggregated['Units'].sum()

plt.bar(['Product 1082', 'Other Products'], [average_revenue_per_unit_1082, average_revenue_per_unit_other])
plt.title('Comparison of Average Revenue per Unit')
plt.ylabel('Average Revenue per Unit')
plt.show()

# %% [markdown]
# ## Is there a consistent pricing strategy for ProductID 1082, given the constant revenue for each unit sold?

# %%
# Filter data for ProductID 1082
product_1082 = df[df['ProductID'] == 1082]

# Check if there is a constant pricing strategy
constant_revenue_per_unit = product_1082['Revenue'].nunique() == 1

# Visualize the relationship between Units and Revenue
plt.scatter(product_1082['Units'], product_1082['Revenue'])
plt.title('Relationship between Units and Revenue for ProductID 1082')
plt.xlabel('Units')
plt.ylabel('Revenue')
plt.show()

# Print information about pricing strategy
if constant_revenue_per_unit:
    print("There is a consistent pricing strategy for ProductID 1082.")
else:
    print("The pricing strategy for ProductID 1082 is not consistent.")
# Out:
# The pricing strategy for ProductID 1082 is not consistent.

# %% [markdown]
# ## Do certain countries prefer this product  (ProductID 1082) more than others?

# %%
# Filter data for ProductID 1082
product_1082 = df[df['ProductID'] == 1082]

# Aggregate data for ProductID 1082 by country
product_1082_by_country = product_1082.groupby('Country').agg({'Units': 'sum', 'Revenue': 'sum'}).reset_index()

# Sort the data by total units sold to highlight top-contributing countries
product_1082_by_country = product_1082_by_country.sort_values(by='Units', ascending=False)

# Visualize sales distribution by country
plt.figure(figsize=(12, 6))
plt.bar(product_1082_by_country['Country'], product_1082_by_country['Units'], color='b')
plt.title('Sales Distribution of ProductID 1082 by Country')
plt.xlabel('Country')
plt.ylabel('Total Units Sold')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##  Are there variations in sales performance between different countries?

# %%
country_aggregated = df.groupby('Country').agg({'Units': 'sum', 'Revenue': 'sum'}).reset_index()

# Sort the data by total revenue to highlight top-contributing countries
country_aggregated = country_aggregated.sort_values(by='Revenue', ascending=False)

# Visualize sales performance by country
plt.figure(figsize=(12, 6))
plt.bar(country_aggregated['Country'], country_aggregated['Revenue'], color='b')
plt.title('Sales Performance by Country')
plt.xlabel('Country')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## What is the overall performance of ProductID 1082 in terms of units sold and revenue generated?

# %%
# Filter data for ProductID 1082
product_1082 = df[df['ProductID'] == 1082]

# Calculate overall performance metrics
total_units_sold = product_1082['Units'].sum()
total_revenue_generated = product_1082['Revenue'].sum()
average_revenue_per_unit = total_revenue_generated / total_units_sold if total_units_sold > 0 else 0

# Print overall performance metrics
print(f"Total Units Sold for ProductID 1082: {total_units_sold}")
print(f"Total Revenue Generated for ProductID 1082: {total_revenue_generated}")
print(f"Average Revenue per Unit for ProductID 1082: {average_revenue_per_unit}")
plt.figure(figsize=(12, 6))
# Visualize overall performance
plt.bar(['Total Units Sold', 'Total Revenue Generated', 'Average Revenue per Unit'],
        [total_units_sold, total_revenue_generated, average_revenue_per_unit])
plt.title('Overall Performance of ProductID 1082')
plt.ylabel('Value')
plt.show()
# Out:
# Total Units Sold for ProductID 1082: 2520
# Total Revenue Generated for ProductID 1082: 580064.2250000001
# Average Revenue per Unit for ProductID 1082: 230.1842162698413
